# %%
import sys
import string
import re
import math
import pandas as pd

# %% [raw]
# # Get the paths
# path_A = '../DATA/imdb3_neg_nan.csv'
# path_B = '../DATA/thenumbers3_neg_nan.csv'
# path_M = '../DATA/MatchPredctionsOnAllTuplePairs.csv'
# A = pd.read_csv(path_A)
# B = pd.read_csv(path_B)
# Matches = pd.read_csv(path_M)
# print(len(Matches))
# Matches.head()

# %%
def merge_title(title1, title2):
    #take the longer title
    title1= title1.item()
    title2=title2.item()
    l1 = len(title1)
    l2= len(title2)
    res = title1 if l1>l2 else title2
    return res

# %%
def merge_year(year1, year2):
    #if value form B exists, take it else from A
    if year2.item() != -1:
        return year2.item()
    return year1.item()

# %%
def merge_mpaa(mpaa1,mpaa2):
    mpaa1=mpaa1.item()
    mpaa2=mpaa2.item()
    return mpaa1 if mpaa1 != "Not Rated" and mpaa1 != "-1" else mpaa2

# %%
def merge_runtime(rt1,rt2):
    rt1=rt1.item()
    rt2=rt2.item()
    regex = re.compile('[^0-9]')
    a=regex.sub('',rt1)
    b=regex.sub('',rt2)
    rt1 = int(a)
    rt2 = int(b)
    rt = rt1 if rt1>rt2 else rt2
    return str(rt)+" min"

# %%
def split_and_union(g1,g2):
    g1 = g1.lower()
    g2= g2.lower()
    g1 = g1.split(",")
    g2= g2.split(",")
    final_list = g1+g2
    final_list = set(final_list)
    
    return ','.join(final_list)

# %%
def merge_genres(g1,g2):
    g1=g1.item()
    g2=g2.item()
    if g1=="-1": return g2
    if g2=="-1": return g1
    return split_and_union(g1,g2)

# %%
def merge_director_name(dir1,dir2):
    dir1=dir1.item()
    dir2=dir2.item()
    if dir1=="-1": return dir2
    if dir2=="-1": return dir1
    return split_and_union(dir1,dir2)

# %%
def merge_stars(stars1, stars2):
    stars1=stars1.item()
    stars2=stars2.item()
    if stars1=="-1": return stars2
    if stars2=="-1": return stars1
    return split_and_union(stars1,stars2)

# %%
def merge_gross(grossL, grossR):
    grossL=grossL.item()
    grossR=grossR.item()
    #remove the '$' or any other special character from gross value of right table-
    #is of the form "$1234,123"
    if grossR == "-1" and grossL == "-1":
        return grossL
    grossRint=grossLint=0
    if grossR != "-1":
        grossclean2 = ''.join(ch for ch in grossR if ch in string.digits)
        grossRint = int(grossclean2)
    #grossL is of the form "$4.4M"
    if grossL != "-1":
        dictL={'M':1e6,'B':1e9,'T':1e12,'k':1e3, 'K':1e3}
        grossL.replace(" ","")
        if grossL[-1] in dictL:
               multfact=dictL[grossL[-1]]
        grossclean1 = ''.join(ch for ch in grossL if ch in string.digits)
        grossLint = float(grossclean1)
        grossLint *= multfact
    f = grossLint if grossLint>grossRint else grossRint
    return "$"+str(f)

# %%
def combine(lt,rt):
    
    a = merge_title(lt.title,rt.title)
    b = merge_year(lt.year,rt.year)
    c=merge_mpaa(lt.mpaa,rt.mpaa)
    d=merge_runtime(lt.runtime,rt.runtime)
    e=merge_genres(lt.genres,rt.genres)
    f=merge_director_name(lt.director,rt.director)
    g=merge_stars(lt.stars,rt.stars)
    h=merge_gross(lt.gross,rt.gross)
    return (lt.id.item(),a,b,c,d,e,f,g,h)

# %%
#pick each tuple from '../DATA/MatchPredctionsOnAllTuplePairs.csv' and take out corresponding
#tuples from A and B
finalist=[]
for row in Matches.itertuples():
    #print(row)
    lid = row.ltable_id
    rid = row.rtable_id
    ltup = A.loc[(A["id"]==lid)]
    rtup = B.loc[(B["id"]==rid)]
    tup = combine(ltup,rtup)
    finalist.append(tup)
df = pd.DataFrame(finalist, columns=['id', 'title', 'year', 'mpaa','runtime','genres','director','stars','gross'])
df.head() 
df.to_csv('../DATA/integrated_table.csv', index=False)

# %%
df.head()
# Out:
#      id                  title  year      mpaa  runtime  \
# 0  1757                 Hamlet  1996     PG-13  242 min
# 1  3547  Home for the Holidays  1995     PG-13  104 min
# 2   502               Hot Fuzz  2007         R  121 min
# 3  3688     Drop Dead Gorgeous  1999     PG-13   97 min
# 4  3517         Bye Bye Birdie  1963  Approved  112 min
#
#                       genres              director  \
# 0                      drama       Kenneth Branagh
# 1      drama, romance,comedy          jodie foster
# 2      action, comedy,comedy          edgar wright
# 3   thriller, romance,comedy  Michael Patrick Jann
# 4     musical,musical,comedy         George Sidney
#
#                                                stars          gross
# 0  kate winslet,kenneth branagh,julie christie,de...   $441000000.0
# 1  charles durning,robert downey jr.,anne bancrof...  $1752000000.0
# 2    bill nighy,nick frost,martin freeman,simon pegg  $2364000000.0
# 3  denise richards,ellen barkin,kirsten dunst,all...  $1056000000.0
# 4  Dick Van Dyke,Ann-Margret,Janet Leigh,Maureen ...  $1313000000.0

# %%
[df[c].unique() for c in df.columns]
# Out:
# [array([1757, 3547,  502, ..., 3408,  296,   62], dtype=int64),
#  array(['Hamlet', 'Home for the Holidays', 'Hot Fuzz', ...,
#         'X-Men Origins: Wolverine', 'X-Men: First Class',
#         'X-Men: Days of Future Past'], dtype=object),
#  array([1996, 1995, 2007, 1999, 1963, 2004, 1988, 2003, 1969, 1989, 2009,
#         2011, 1956, 2008, 1991, 2010, 1998, 2001, 1968, 1994, 1992, 1978,
#         1982, 1964, 1981, 1980, 1990, 1997, 1962, 1984, 1979, 2015, 1993,
#         2005, 1971, 1974, 1976, 1987, 2000, 1977, 1957, 1935, 1985, 1942,
#         1939, 1961, 1983, 1936, 2012, 2014, 1932, 1986, 2002, 1975, 2013,
#         2006, 1947, 1972, 1973, 1967, 1958, 1960, 1955, 1966, 1950, 1941,
#         1970, 1945, 1923, 1920, 1946, 1925, 1937, 1953, 1944, 1927, 1915,
#         1948, 1965, 1951, 1931, 1940, 1959, 1952, 1934, 1943, 1954, 1922,
#         1930, 1938, 1933, 1949, 2016, 1921, 1924, 1926, 1928], dtype=int64),
#  array(['PG-13', 'R', 'Approved', 'PG', 'M/PG', 'G', '-1', 'Not Rated',
#         'Unrated', 'NC-17', 'GP', 'M', 'Passed', 'TV-14', 'TV-MA', 'X',
#         'TV-G'], dtype=object),
#  array(['242 min', '104 min', '121 min', '97 min', '112 min', '114 min',
#         '138 min', '110 min', '73 min', '119 min', '99 min', '96 min',
#         '95 min', '108 min', '98 min', '102 min', '136 min', '86 min',
#         '92 min', '170 min', '120 min', '131 min', '105 min', '178 min',
#         '117 min', '151 min', '106 min', '118 min', '88 min', '128 min',
#         '134 min', '122 min', '94 min', '84 min', '133 min', '103 min',
#         '85 min', '164 min', '125 min', '130 min', '135 min', '147 min',
#         '176 min', '161 min', '142 min', '75 min', '129 min', '111 min',
#         '101 min', '159 min', '115 min', '91 min', '93 min', '143 min',
#         '132 min', '127 min', '126 min', '165 min', '89 min', '63 min',
#         '157 min', '113 min', '124 min', '167 min', '145 min', '107 min',
#         '77 min', '116 min', '82 min', '141 min', '109 min', '144 min',
#         '162 min', '155 min', '100 min', '140 min', '123 min', '87 min',
#         '160 min', '137 min', '153 min', '64 min', '158 min', '74 min',
#         '150 min', '139 min', '146 min', '182 min', '78 min', '81 min',
#         '83 min', '90 min', '79 min', '80 min', '154 min', '210 min',
#         '67 min', '195 min', '201 min', '179 min', '26 min', '148 min',
#         '172 min', '166 min', '205 min', '192 min', '197 min', '181 min',
#         '191 min', '169 min', '184 min', '189 min', '225 min', '152 min',
#         '71 min', '212 min', '76 min', '149 min', '384 min', '238 min',
#         '30 min', '206 min', '180 min', '186 min', '175 min', '202 min',
#         '325 min', '185 min', '216 min', '208 min', '224 min', '229 min',
#         '187 min', '68 min', '59 min', '70 min', '72 min', '219 min',
#         '171 min', '69 min', '271 min', '174 min', '156 min', '566 min',
#         '163 min', '194 min', '193 min', '220 min', '173 min'],
#        dtype=object),
#  array(['drama', ' drama, romance,comedy', 'action, comedy,comedy',
#         ' thriller, romance,comedy', ' musical,musical,comedy',
#         'thriller/suspense,sci-fi, thriller',
#         'crime,drama, drama, mystery', 'biography, crime,western, drama',
#         ' drama, crime,comedy', ' horror, sci-fi,comedy',
#         ' mystery, crime,comedy', 'comedy,action, comedy, fantasy',
#         ' drama, sport,comedy', 'drama,biography, drama',
#         ' drama, crime,black comedy,comedy', 'drama,black comedy',
#         ' mystery,drama,thriller/suspense, thriller',
#         'drama,biography, crime, drama', ' mystery,action, crime',
#         ' crime,comedy', 'drama, romance, sport,comedy',
#         ' drama, family,comedy', ' adventure, comedy,animation,adventure',
#         'action, comedy,horror, fantasy', ' music,drama,biography, drama',
#         'comedy', 'drama,musical, family, musical',
#         ' comedy,adventure, drama,comedy', 'Biography, Comedy, Drama',
#         'crime,drama, drama', ' fantasy, drama,comedy',
#         'drama, war, thriller', 'Adventure, Drama, History',
#         ' sci-fi,comedy', 'horror, sci-fi', 'drama, romance',
#         ' romance, musical,musical,comedy',
#         ' mystery,romantic comedy, drama,comedy', 'Comedy, Drama',
#         'documentary, sport', 'crime,thriller/suspense, drama, mystery',
#         'drama, thriller', ' mystery, thriller,comedy',
#         ' comedy,adventure, family', 'drama,black comedy, thriller',
#         'action, adventure,adventure, comedy', 'drama, history, thriller',
#         ' romance, sport,comedy', 'drama,biography, romance, drama',
#         'action, adventure,adventure, fantasy', ' drama,comedy',
#         ' sci-fi, romance,comedy',
#         'romantic comedy, drama, romance,comedy',
#         ' mystery,drama, thriller', 'drama, war,action, history',
#         ' war, drama,adventure,drama',
#         'drama, history,thriller/suspense, thriller', ' romance,comedy',
#         ' adventure,animation, family,adventure',
#         'drama, horror, sci-fi,horror', 'drama, romance,musical',
#         'drama, war, romance', 'drama,biography, history, drama',
#         'drama, drama,comedy', 'drama, drama, romance,comedy',
#         'action, drama, crime,thriller/suspense', 'drama, music',
#         'Comedy, Drama, Romance', 'drama, sci-fi,black comedy',
#         'thriller/suspense,biography, crime, drama',
#         'action, comedy, crime', 'drama, romance, sport',
#         'drama, romance, musical,musical',
#         'drama, drama, biography,adventure', 'horror, thriller',
#         'drama,thriller/suspense, thriller',
#         ' thriller, horror,horror,comedy', 'Action, Adventure, Fantasy',
#         'crime,drama, drama, thriller', 'drama, war',
#         'Adventure, Horror, Mystery', 'drama, drama,adventure, thriller',
#         'crime,drama, drama, romance', ' musical,comedy',
#         'Crime, Drama, Mystery', ' crime, drama,documentary',
#         'drama,action, adventure, drama',
#         ' mystery,action,thriller/suspense, thriller',
#         ' mystery,action, adventure,thriller/suspense', 'drama, history',
#         'action, drama, fantasy',
#         'crime,thriller/suspense, romance, thriller',
#         'action, adventure, fantasy', ' mystery,drama, music',
#         'drama, romance, fantasy', 'action, drama, crime,comedy',
#         'action, adventure, sci-fi', 'drama, comedy,adventure, drama',
#         ' mystery,drama, sci-fi,thriller/suspense',
#         'drama, war,biography, drama', ' comedy,adventure,comedy',
#         ' horror, sci-fi,horror,comedy',
#         'concert/performance, comedy,documentary',
#         'comedy, comedy,adventure, fantasy', 'action, drama, thriller',
#         'drama, horror,horror, fantasy', 'drama, sci-fi, thriller',
#         'action, comedy, fantasy', ' fantasy, horror,horror,comedy',
#         'drama, sport', ' fantasy, romance,comedy',
#         'drama, musical, music', 'action, adventure, sci-fi,adventure',
#         ' romance,adventure,comedy', 'drama, romance, music',
#         'action, adventure, drama', 'action, horror, sci-fi,horror',
#         'action, crime, biography,drama', 'Drama, Horror, Sci-Fi',
#         'action, crime, thriller', 'drama,biography, sport, drama',
#         'fantasy, horror,horror', 'action, adventure, comedy,comedy',
#         'drama, horror,thriller/suspense, fantasy',
#         'crime,thriller/suspense, drama, romance',
#         'drama, drama, music,comedy', 'Adventure, Drama, Western',
#         ' crime,documentary', 'crime, horror,horror, mystery',
#         ' mystery,horror, thriller', 'action, comedy, sci-fi',
#         ' mystery,action, drama,drama', ' mystery,drama, romance',
#         'romantic comedy, romance,comedy',
#         ' action, adventure,animation,adventure',
#         'crime,drama, drama, music',
#         'action, drama, romance,thriller/suspense',
#         'thriller/suspense,mystery, thriller', ' drama,adventure',
#         'action, drama, crime,horror',
#         ' drama,animation, family,adventure', 'Comedy, Drama, War',
#         ' mystery, sci-fi,adventure',
#         'adventure,animation, family, fantasy',
#         ' comedy, crime,adventure,musical', 'Drama, Western',
#         'crime,drama, drama, history', 'horror, sci-fi, thriller',
#         'action, drama, crime', 'drama, drama,adventure, history',
#         'action, adventure, thriller', 'action, drama, sport',
#         'Action, Adventure, Western', 'crime,drama, drama, fantasy',
#         'Crime, Drama', 'drama,comedy',
#         'thriller/suspense,biography, history, drama',
#         'drama, drama, crime,comedy', 'biography, drama, comedy,comedy',
#         'drama, war, history', ' war,comedy', 'Crime, Drama, Film-Noir',
#         'action, drama, biography', 'action, comedy, crime,comedy',
#         'Drama, Romance, Western',
#         'crime,thriller/suspense, drama, thriller',
#         'drama,musical, history, musical', ' romance, family,comedy',
#         'adventure, family, fantasy', ' mystery,drama, sci-fi',
#         'drama,adventure, fantasy', 'drama, horror,action, fantasy',
#         'action, drama,adventure, thriller', 'horror',
#         ' adventure, drama,animation,adventure',
#         'drama, drama, sci-fi,adventure', 'Action, Sci-Fi',
#         'action, adventure, crime', 'crime,drama, thriller',
#         'drama,biography, crime, comedy', 'crime,action, drama',
#         'Drama, Sport', ' western,comedy',
#         'action, adventure,adventure, horror', 'action, crime, sci-fi',
#         'action,adventure, fantasy',
#         ' adventure, comedy,animation,musical', ' mystery,horror',
#         'action, horror, sci-fi', 'action, horror', ' music,comedy',
#         'thriller/suspense,biography, drama, thriller',
#         ' thriller, crime,comedy', ' drama,documentary',
#         'action, sci-fi, thriller',
#         'action, adventure,thriller/suspense, thriller',
#         'action, adventure, sci-fi,thriller/suspense',
#         'thriller/suspense, sci-fi,adventure, thriller',
#         'action,thriller/suspense, thriller',
#         'drama, sport,adventure, family', 'action, drama, history,drama',
#         ' drama, music,comedy',
#         ' fantasy, horror,thriller/suspense,comedy',
#         'drama,horror, romance', ' mystery,action, adventure,adventure',
#         'drama, horror, romance', 'action, drama, biography,drama',
#         'action, crime,thriller/suspense, thriller',
#         'romantic comedy, fantasy, romance,comedy',
#         'Biography, Crime, Drama', 'Drama', 'Drama, War',
#         'horror, romance', 'Action, Comedy', 'Adventure, Fantasy, Sci-Fi',
#         'Drama, Film-Noir', ' drama,adventure, family',
#         ' mystery,drama, horror,thriller/suspense',
#         'crime, drama,western, romance', 'action, adventure, comedy',
#         'Comedy, Crime, Drama', 'drama,biography, drama, thriller',
#         'thriller/suspense, drama, crime,comedy',
#         'Action, Adventure, Drama', 'Adventure, Drama, Fantasy',
#         'drama, war,action', ' mystery,drama', ' horror,horror,comedy',
#         'Comedy, Musical', 'crime,drama, drama, film-noir',
#         'crime,action, drama, thriller', ' mystery,drama, horror,horror',
#         'drama, sci-fi,action', ' drama,black comedy,comedy',
#         'documentary, music', 'action, comedy, crime,drama',
#         'drama, horror', ' fantasy,black comedy,comedy',
#         'action,biography, sport, drama', 'Animation, Adventure, Fantasy',
#         ' drama,adventure, fantasy', ' comedy,animation, family,adventure',
#         ' drama,adventure, thriller', 'Drama, Family',
#         'drama, sci-fi, romance',
#         'drama, horror,thriller/suspense, thriller',
#         ' comedy, romance,animation,adventure',
#         'thriller/suspense,horror, sci-fi', 'action, drama, war,drama',
#         ' drama, sci-fi,adventure,comedy',
#         ' comedy,animation,adventure, drama',
#         'musical,biography, musical, comedy', 'Horror',
#         'action, drama, history', ' drama, family,musical,comedy',
#         'crime,thriller/suspense, thriller', 'action,western',
#         'Animation, Adventure, Comedy',
#         'crime,thriller/suspense, film-noir, mystery',
#         'drama,biography, drama, comedy',
#         ' mystery,drama,horror, thriller',
#         ' crime, musical,musical,comedy', 'western',
#         'drama, drama,adventure, fantasy', 'Crime, Drama, Sci-Fi',
#         'drama, sci-fi,adventure', ' western,romance,western',
#         'action, drama, war', 'Biography, Drama, Western',
#         'Drama, Romance, War',
#         ' mystery,thriller/suspense,horror, thriller',
#         'action, horror, crime,horror', 'Animation, Family, Music',
#         'drama, sci-fi,thriller/suspense, fantasy',
#         'thriller/suspense,thriller', ' sport,comedy',
#         'horror,documentary, thriller', ' western, drama,comedy',
#         'action, adventure, family,adventure',
#         'documentary, biography, sport',
#         ' action, comedy,animation,adventure',
#         'action, comedy,horror, horror', 'Adventure, Sci-Fi',
#         ' fantasy, musical,musical,comedy', ' drama,documentary, sport',
#         'action, drama, sport,drama', 'comedy,action, adventure, thriller',
#         ' adventure, drama,animation,musical', 'Comedy, Drama, Family',
#         'Drama, Romance', ' thriller,romantic comedy, romance,comedy',
#         'drama, romance, family', 'musical, drama, music,comedy',
#         'drama, war,western, romance', 'drama,western, western',
#         'action, comedy, crime,black comedy', 'Action, Crime, Drama',
#         'action, drama, crime,drama', ' romance, music,comedy',
#         'musical, family, musical,comedy', 'drama, family, fantasy',
#         'documentary, biography', 'action, horror,horror, thriller',
#         'Adventure, Comedy, Musical', ' comedy,adventure, drama',
#         ' fantasy, horror,comedy', 'animation, family,musical, fantasy',
#         'crime,thriller/suspense, mystery, thriller',
#         'romantic comedy,comedy', 'drama, drama,animation, fantasy',
#         'crime,drama, drama, sport', 'Adventure, Biography, Drama',
#         ' western,western, romance,comedy', ' family,comedy', 'Western',
#         'crime, drama,documentary', 'drama, fantasy',
#         'drama, film-noir, romance,thriller/suspense',
#         'Adventure, Comedy, Drama', 'Animation, Short, Comedy',
#         'Drama, Family, Romance',
#         'drama, sci-fi,thriller/suspense, thriller',
#         'crime, drama,black comedy', 'drama, drama,animation, music',
#         'Crime, Drama, Romance', 'Action, Adventure, War',
#         ' comedy, crime,adventure', 'action, adventure,western, comedy',
#         ' comedy,documentary,comedy', 'action, crime,adventure, thriller',
#         ' drama, romance,adventure',
#         'thriller/suspense, sci-fi,mystery, thriller',
#         ' fantasy, family,comedy', 'adventure, fantasy',
#         ' romance,musical', 'Action, Adventure, Sci-Fi', 'action, sci-fi',
#         'Drama, History', 'adventure, fantasy, family,comedy',
#         'Comedy, Drama, Sport', ' mystery,action,adventure, thriller',
#         ' drama,adventure, history',
#         ' adventure,family,adventure, animation', 'horror,thriller',
#         ' comedy, sci-fi,adventure', 'drama, sci-fi',
#         'drama, romance,thriller/suspense, thriller',
#         'action, adventure, romance', 'Comedy, Romance',
#         'action, horror,horror, fantasy', ' history,comedy',
#         'action, thriller', 'action, adventure,adventure, drama',
#         ' mystery,action, horror,horror', 'drama, war,thriller/suspense',
#         ' western,biography,western', ' fantasy,comedy',
#         'action, drama, biography,adventure',
#         'action, drama,thriller/suspense, thriller',
#         ' fantasy, family,musical,comedy', ' fantasy, crime,comedy',
#         ' adventure, comedy,animation,drama',
#         'crime,thriller/suspense, film-noir, thriller',
#         'action, romance,thriller/suspense, thriller',
#         ' fantasy, drama,black comedy,comedy',
#         'drama, drama,animation, biography',
#         'romantic comedy,drama, romance', 'drama, horror,horror',
#         'thriller/suspense, drama, sci-fi,adventure',
#         'fantasy, romance,drama', 'Comedy, Musical, Romance',
#         'crime, horror,horror', ' mystery, drama,comedy',
#         ' drama,multiple genres,adventure, history',
#         ' crime, romance,comedy', ' western,western,mystery',
#         'Action, Drama, Thriller', 'Comedy',
#         'drama, romance,musical, music', 'action, drama, sci-fi',
#         'action, comedy, crime,adventure', 'Action, Adventure, Romance',
#         ' thriller,action, drama,comedy',
#         ' action, adventure,action,animation',
#         ' action, sci-fi,animation,action',
#         'action, comedy, crime,documentary',
#         ' mystery, horror,horror,adventure', ' mystery,drama, fantasy',
#         ' mystery, horror,horror,comedy', ' drama, sci-fi,adventure',
#         'drama, romance,comedy', 'Crime, Thriller',
#         'action, sci-fi,adventure, thriller',
#         'drama,biography, drama, fantasy', 'Animation, Comedy, Family',
#         ' adventure,animation, family,musical',
#         'fantasy, comedy, romance,comedy', 'drama, romance, history',
#         'Animation, Family, Musical',
#         'thriller/suspense,action, adventure, drama',
#         ' comedy, short,animation,adventure',
#         'action, adventure, romance,adventure', 'Thriller, War',
#         'black comedy,comedy', 'Adventure, Horror, Sci-Fi',
#         'Drama, Horror, Thriller',
#         'crime,thriller/suspense, horror, mystery', ' mystery,comedy',
#         ' sci-fi,adventure, family', ' mystery, romance,comedy',
#         'Crime, Mystery, Thriller', 'biography, romance, drama,comedy',
#         'romantic comedy, war, romance,comedy',
#         'drama, drama, romance,adventure', 'Drama, Thriller',
#         'action, comedy, crime,horror', 'Biography, Drama, War',
#         ' comedy, sci-fi,adventure,comedy',
#         'musical, comedy,adventure, musical', 'Action, Horror, Sci-Fi',
#         'Animation, Action, Adventure', 'action, drama,adventure',
#         'drama, horror, sci-fi,thriller/suspense',
#         'drama,adventure, thriller', 'drama, drama,sci-fi',
#         'action, sci-fi,drama', ' war, drama,action,adventure',
#         'Comedy, Drama, Music', 'drama, drama,adventure',
#         'action, drama,western, romance', 'action, horror, fantasy',
#         'thriller/suspense, drama,adventure, thriller',
#         'Adventure, Family, Fantasy', ' adventure,family,drama',
#         'film-noir,thriller/suspense, thriller', ' drama, sci-fi,comedy',
#         'drama, sport, fantasy', 'Action, Biography, Drama',
#         'action, adventure,adventure', ' action, crime,animation,action',
#         'Adventure, Comedy, Crime', ' fantasy, drama,drama,comedy',
#         'drama, sci-fi, fantasy', 'Biography, Drama, History',
#         ' western, drama,adventure,drama', 'documentary',
#         ' war,romance,thriller/suspense, thriller', 'action, adventure',
#         'Drama, Film-Noir, Romance', ' drama,western,adventure, history',
#         ' adventure,animation,adventure, fantasy',
#         'action, adventure, romance,drama', 'Drama, Family, History',
#         ' horror,black comedy,comedy', ' mystery,drama, war',
#         'crime,action, thriller', 'drama,musical, musical, music',
#         'romantic comedy,drama, romance, fantasy',
#         ' thriller,drama, drama,comedy', 'film-noir,drama, mystery',
#         'action, sci-fi,thriller/suspense, thriller', ' war,documentary',
#         'action, horror,adventure', ' horror, sci-fi,horror,adventure',
#         'biography, history, drama,adventure', ' crime, music,comedy',
#         'action, comedy, drama', 'action,biography, history, drama',
#         'Biography, Drama, Musical',
#         'concert/performance, drama, romance,comedy',
#         ' drama, biography,adventure', 'drama,biography, family, drama',
#         'Action, Thriller', 'Comedy, Family, Romance',
#         'Action, Drama, History', ' crime, comedy,documentary',
#         'Action, Comedy, Sci-Fi', ' war, drama,comedy',
#         'Adventure, Drama, Musical',
#         'thriller/suspense,horror, sci-fi, thriller',
#         'fantasy, horror,drama, thriller', ' western, romance,comedy',
#         'crime, war, drama,drama', ' horror, sci-fi,black comedy,comedy',
#         ' comedy,adventure, fantasy', 'drama,horror',
#         ' crime,documentary, biography', 'Drama, Romance, Sci-Fi',
#         'action, adventure, sci-fi,comedy',
#         'musical,biography, history, drama',
#         ' mystery,drama,thriller/suspense',
#         'fantasy, horror,horror, thriller', 'crime, drama,horror, fantasy',
#         'Action, Sci-Fi, Thriller', 'Drama, Horror',
#         'crime, drama,western, mystery',
#         'crime,thriller/suspense, drama, film-noir',
#         'action, comedy, romance,comedy', 'drama, drama,animation, family',
#         'documentary, biography, music', 'Comedy, Musical, Western',
#         'action, sport, thriller', 'action, comedy,black comedy',
#         'Comedy, Horror, Thriller', 'Horror, Thriller',
#         ' mystery,adventure, fantasy', 'Drama, Family, Sport',
#         ' comedy, romance,adventure', ' drama,western, romance,comedy',
#         'action, drama,drama, thriller',
#         'black comedy, drama, romance,comedy', 'action,sci-fi, thriller',
#         'thriller/suspense,horror, thriller',
#         'action, comedy,adventure, fantasy',
#         'thriller/suspense,romance, sci-fi, thriller',
#         'drama, sci-fi, romance,comedy', 'drama, sci-fi,family',
#         'Crime, Drama, Sport', 'Horror, Mystery',
#         'action, crime,horror, thriller', 'drama, horror,horror, thriller',
#         'action, drama, sci-fi,animation', ' war, comedy,adventure,comedy',
#         'action, adventure,western, drama', ' musical, music,comedy',
#         'drama, comedy,documentary, drama',
#         'action,western, romance, thriller', 'Drama, Music, Musical',
#         'Crime, Drama, Thriller', 'crime,adventure, thriller',
#         'Horror, Mystery, Thriller', 'action, comedy, sport',
#         ' drama,horror,adventure, horror',
#         ' drama,horror,adventure, thriller',
#         'drama, musical,musical, fantasy',
#         ' comedy,adventure, music,comedy', 'Comedy, Horror',
#         ' comedy, crime,adventure,comedy', 'Comedy, Romance, War',
#         'crime, drama,horror, thriller', 'action, drama, family',
#         'action, romance, family', 'action, comedy,adventure, drama',
#         'drama, film-noir', 'romantic comedy, drama,comedy',
#         'Adventure, Comedy, Romance', 'action, drama, sci-fi,adventure',
#         ' western,biography,western, drama', 'action, crime, fantasy',
#         'musical,adventure, musical, fantasy', 'drama, romance, thriller',
#         'romantic comedy, fantasy, drama,comedy', 'Drama, Mystery, Sci-Fi',
#         ' action, comedy,documentary,comedy',
#         'thriller/suspense,biography, romance, drama',
#         ' mystery,horror, sci-fi', ' mystery,action, crime,drama',
#         'adventure, drama, family,comedy', 'Adventure, Family, Sci-Fi',
#         'action, sci-fi,adventure, fantasy', 'Comedy, Drama, Musical',
#         ' thriller, drama,comedy', 'fantasy, horror,thriller/suspense',
#         'drama, musical,musical', ' western, drama,western,adventure',
#         ' thriller,black comedy,comedy',
#         'romantic comedy, comedy,animation, family',
#         'crime, drama, musical,musical', ' war, drama,documentary',
#         'drama, romance, music,comedy', 'Biography, Drama',
#         'drama,western, romance, western', 'drama, sport, history',
#         'comedy,drama, romance, fantasy', ' crime,black comedy,comedy',
#         'Adventure, Drama', 'Musical, Romance', ' comedy,adventure, music',
#         'action, war', 'Adventure, Family', 'drama,musical, music',
#         'romantic comedy, drama, music,comedy',
#         'drama, horror, musical,musical', ' comedy,documentary, drama',
#         'black comedy, sci-fi,mystery, thriller',
#         'Drama, Mystery, Thriller', 'Action, Comedy, Drama',
#         'concert/performance,documentary, music',
#         'Horror, Mystery, Sci-Fi', 'action, comedy, drama,comedy',
#         'romance, sci-fi,adventure', 'Drama, Musical, Romance',
#         ' comedy,adventure',
#         'film-noir,thriller/suspense, romance, mystery',
#         'crime,thriller/suspense, sci-fi, mystery',
#         'comedy, comedy,animation, fantasy',
#         'thriller/suspense, sci-fi, romance,mystery',
#         'musical,biography, family, drama', 'Drama, Film-Noir, Mystery',
#         ' mystery,fantasy,horror, thriller',
#         'black comedy, romance,comedy', 'Drama, Mystery',
#         ' mystery,fantasy, horror,horror',
#         'drama,animation, family, fantasy', ' mystery,drama, drama,comedy',
#         ' crime, family,comedy',
#         'thriller/suspense, drama, crime,adventure',
#         'Action, Comedy, Crime', 'action, drama, crime,western',
#         ' war,action, romance,adventure',
#         'drama, sci-fi,mystery, thriller', ' sci-fi, family,comedy',
#         ' drama, romance,multiple genres,comedy',
#         ' war,documentary, history', 'drama, drama, sci-fi,comedy',
#         'Musical, Comedy', 'action, comedy, thriller',
#         'drama,action, romance, history',
#         ' mystery,thriller/suspense,comedy',
#         'action, adventure, crime,adventure', ' horror,comedy',
#         'comedy,action, horror, thriller', 'action, horror,comedy',
#         'romantic comedy, drama, history,comedy',
#         'action, comedy,black comedy, horror', 'Comedy, War',
#         'action, drama, romance', 'Crime, Drama, Music',
#         ' crime, biography,adventure,western', 'drama, musical',
#         'action, drama,western, biography', 'Adventure, Comedy, History',
#         'drama, film-noir,thriller/suspense',
#         'Animation, Adventure, Family', 'action, comedy, sci-fi,comedy',
#         'action, adventure, horror',
#         'thriller/suspense, romance,mystery, thriller',
#         'drama, drama, family,comedy', 'drama, romance,thriller/suspense',
#         'documentary, history, music', 'drama, sport, family',
#         'drama, family,musical, fantasy', 'Adventure, Drama, Sci-Fi',
#         'biography, crime,black comedy, comedy',
#         'drama, horror, romance,thriller/suspense',
#         'musical,adventure, family, fantasy', 'Action, Sci-Fi, Sport',
#         ' family, music,comedy', ' comedy,horror,adventure, family',
#         'drama,action, sport', 'action, adventure, family',
#         'thriller/suspense, drama, crime,animation', 'Mystery, Thriller',
#         ' comedy,adventure, musical,comedy', 'Adventure, Drama, Romance',
#         'drama, biography,adventure, history', 'Action, Drama, Western',
#         'drama, drama, sport,comedy', 'crime,drama, romance, thriller',
#         'Family, Fantasy, Musical', 'Drama, Horror, Romance',
#         'drama, horror,horror, romance',
#         'action, adventure,western, western', 'Action, Drama, Romance',
#         'action, horror, sci-fi,thriller/suspense',
#         ' war,western, romance,adventure', 'Horror, Sci-Fi',
#         'action, drama, crime,adventure', 'Documentary, Family, Musical',
#         'drama, war, sci-fi', ' mystery,drama,biography, drama',
#         ' thriller,comedy', 'drama, sport,comedy',
#         'biography, comedy,comedy', 'Crime, Drama, Horror',
#         ' adventure, crime,animation,adventure', ' crime, sci-fi,comedy',
#         ' fantasy,adventure,comedy', ' war, comedy,documentary',
#         'romantic comedy, romance, music,comedy',
#         'action, comedy, sport,comedy', 'action, drama',
#         ' mystery,action, drama', 'Comedy, Crime',
#         'romantic comedy, horror, romance,comedy',
#         'Adventure, Sci-Fi, Thriller', 'comedy, horror,adventure, fantasy',
#         'crime,drama, mystery, thriller',
#         ' drama,documentary,animation, biography', 'action, drama,drama',
#         'drama, romance, western', 'action, war, thriller',
#         'Comedy, Music', 'crime,thriller/suspense, drama, horror',
#         'Thriller', ' comedy,adventure, horror,comedy',
#         'crime,thriller/suspense, drama, history',
#         'drama, war,action, sport', 'action,western, western',
#         ' thriller, crime,black comedy,comedy', 'Adventure, Western',
#         ' mystery,fantasy, romance,thriller/suspense',
#         ' thriller,action, fantasy', 'Fantasy, Horror',
#         'drama, sci-fi,horror, thriller',
#         'biography,multiple genres, musical, drama'], dtype=object),
#  array(['Kenneth Branagh', 'jodie foster', 'edgar wright', ...,
#         'steven c. miller,jonathan glazer', 'jay levey', 'stuart baird'],
#        dtype=object),
#  array(['kate winslet,kenneth branagh,julie christie,derek jacobi',
#         'charles durning,robert downey jr.,anne bancroft,holly hunter',
#         'bill nighy,nick frost,martin freeman,simon pegg', ...,
#         'liev schreiber,hugh jackman,danny huston,ryan reynolds',
#         'michael fassbender,james mcavoy,jennifer lawrence,kevin bacon',
#         'hugh jackman,jennifer lawrence,patrick stewart,michael fassbender,ian mckellen,james mcavoy'],
#        dtype=object),
#  array(['$441000000.0', '$1752000000.0', '$2364000000.0', ...,
#         '$17988000000.0', '$14641000000.0', '$23392000000.0'], dtype=object)]

# %%
len(df)
# Out:
# 2674
